# %% [markdown]
# # Scraping &Other Stories product images
# ***

# %% [markdown]
# ### 0. Import all necessary libraries

# %%
import numpy as np
import time
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import urllib
import cv2

# %% [markdown]
# ### 1. Get image link for all products

# %%
urls = ["https://www.stories.com/en_usd/bags/shoulder-bags.html",
        "https://www.stories.com/en_usd/bags/bum-bags.html",
        "https://www.stories.com/en_usd/bags/totes.html"]

test_ = "https://www.stories.com/en_usd/bags/all/_jcr_content/subdepartmentPar/productlisting_3521.products.html?start=20"

# %%
links=[]
desc=[]
prices=[]
page = requests.get(test_)
soup = BeautifulSoup(page.content, 'xml')
match = soup.findAll('div', {'class':'product-image'})
# match2 = [m.find('img') for m in match]
# links.extend([x['data-src'] for x in match2])
# desc.extend([x['alt'] for x in match2])
# match3 = ('span', {'class': 'price'}) # find all tags with prices
# prices.extend([price for price in match3])

# %%
print(soup)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE HTML>
# <html class="no-js" lang="en">
# <head>
# <title> Other Stories - Create your own fashion story - Online shop - US</title><meta content="Women's clothing, shoes, bags, accessories and beauty. Free shipping &amp; free returns." name="description">
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport">
# <meta content="telephone=no" name="format-detection">
# <meta content="text/html; charset=UTF-8" http-equiv="content-type">
# <meta content="" name="keywords">
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <meta content="A3340B19B3D0C1898AD9E234EA73D953" name="msvalidate.01"/>
# <meta content=" Other Stories - Create your own fashion story - Online shop - US" property="og:title">
# <meta content="Women's clothing, shoes, bags, accessories and beauty. Free shipping &amp; free returns." property="og:description">
# ...

# %%
# list of dictionary in dataframe
df_data = pd.DataFrame(all_data)
df_data
# Out:
#                        description  \
# 0    Bucket Bag with Suede Details
# 1               Straw Shoulder Bag
# 2              Paper Straw Shopper
# 3                     Mini Shopper
# 4                          Net Bag
# 5                    Suede Shopper
# 6                  Round Straw Bag
# 7                  Braided Handbag
# 8        Straw Bag with Fabric Bag
# 9               Suede Shoulder Bag
# 10              Small Shoulder Bag
# 11           Waist Belt with Pouch
# 12             Transparent Shopper
# 13                 Small Straw Bag
# 14                        Belt Bag
# 15                  Small Backpack
# 16                        Belt Bag
# 17             Small Suede Shopper
# 18                  Small Backpack
# 19  Shoulder Bag with Suede Detail
# 20                             Bag
# 21              Suede Shoulder Bag
# 22                    Shoulder Bag
# 23                         Shopper
# 24                  Mini Pouch Bag
# ...

# %%
# save the dataframe as a csv (to merge with other data later)
df_data.to_csv('otherstories_data.csv')

# %% [markdown]
# ### 2. Loop through image links and save as a .png file

# %%
# loop through the links to request and save image
for i, url in enumerate(links):
    time.sleep(1)
    try:
        request = urllib.request.Request(url)
        response = urllib.request.urlopen(request)
        binary_str = response.read()
        byte_array = bytearray(binary_str)
        numpy_array = np.asarray(byte_array, dtype='int8')
        image = cv2.imdecode(numpy_array, cv2.IMREAD_UNCHANGED)
        cv2.imwrite("H&M/"+"hm_{}".format(i+1)+".png", image)
        print("Saved "+"hm_{}".format(i+1)+".png")
    except Exception as e:
        print(str(e))

print("Done")
# Out:
# Saved hm_0.png
# Saved hm_1.png
# Saved hm_2.png
# Saved hm_3.png
# Saved hm_4.png
# Saved hm_5.png
# Saved hm_6.png
# Saved hm_7.png
# Saved hm_8.png
# Saved hm_9.png
# Saved hm_10.png
# Saved hm_11.png
# Saved hm_12.png
# Saved hm_13.png
# Saved hm_14.png
# Saved hm_15.png
# Saved hm_16.png
# Saved hm_17.png
# Saved hm_18.png
# Saved hm_19.png
# Saved hm_20.png
# Saved hm_21.png
# Saved hm_22.png
# Saved hm_23.png
# Saved hm_24.png
# Saved hm_25.png
# Saved hm_26.png
# Saved hm_27.png
# Saved hm_28.png
# Done
