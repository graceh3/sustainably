# %% [markdown]
# # Scraping H&M product images
# ***

# %% [markdown]
# ### 0. Import all necessary libraries

# %%
import numpy as np
import time
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import urllib
import pandas as pd
import cv2

# %% [markdown]
# ### 1. Get image link for all products

# %%
url = "https://www2.hm.com/en_us/women/new-arrivals/shoes-accessories.html?sort=stock&productTypes=bag&image-size=small&image=stillLife&offset=0&page-size=36"
hm_page = requests.get(url)
soup = BeautifulSoup(hm_page.content, 'lxml')

# %%
# get all image links
match = soup.findAll('img', {"class":"item-image"}) # find all tags with images
links = [x['data-altimage'] for x in match] # get image links to save pic
desc = [x['alt'] for x in match] # get item descriptions
match2 = soup.findAll('span', {'class': 'price regular'}) # find all tags with prices
prices = [price.text for price in match2] # get item prices

# %%
# update the links that were
links_= []
for l in links:
    l = l.replace('[m]','[y]')
    l = l.replace('style', 'main')
    l = 'http:'+l
    links_.append(l)

# %%
# create a list of dictionaries with item details
all_data = []
"http:"+(url.replace('[m]', '[y]').replace('style', 'main'))
for i in range(len(links)):
    all_data.append({"link": links_[i], "description": desc[i], "price": prices[i]})
all_data
# Out:
# [{'link': 'http://lp2.hm.com/hmgoepprod?set=source[/14/19/1419903843a7b4bbd0b497c8189e43061fb18056.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Bucket Bag with Suede Details',
#   'price': '$49.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/9e/36/9e362586554b101dcc2745227fec6a93bc9a5c45.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Straw Shoulder Bag',
#   'price': '$19.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/19/58/19581a1612861d63e710ab471eac47fc8b2e515d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Paper Straw Shopper',
#   'price': '$29.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/21/8c/218cea81e997d7f320a8bd005662667462532d8a.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Mini Shopper',
#   'price': '$19.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/b2/bf/b2bf91e230e4c12ade0ffda37e16f0c9c6990c2f.jpg],origin[dam],category[ladies_bags_shopperstotes],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Net Bag',
#   'price': '$14.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/90/8c/908c614e40202791744fec46e3e530636cf866a3.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Suede Shopper',
#   'price': '$69.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/ce/67/ce678ca65ef3a0b659dac5fc56cdbff81c408a23.jpg],origin[dam],category[ladies_bags_shopperstotes],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Round Straw Bag',
#   'price': '$17.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/36/ed/36edafc35022fc14725e63f6cfd8121804f5543d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Braided Handbag',
#   'price': '$59.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/e2/2f/e22f5d532f472042037bdd26030b3190d358cc79.jpg],origin[dam],category[ladies_bags_shopperstotes],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Straw Bag with Fabric Bag',
#   'price': '$29.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/6f/91/6f91ba24ebd4961d3de41257256b1a3426763756.jpg],origin[dam],category[ladies_bags_shouldercross],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Suede Shoulder Bag',
#   'price': '$49.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/dc/2e/dc2eebf7c1432acbc65619ca51e058d5c5c4a4f4.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Small Shoulder Bag',
#   'price': '$29.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/d4/e9/d4e9fef3d71b409503593b728f5813ce884afb1c.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Waist Belt with Pouch',
#   'price': '$17.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/21/bb/21bb89ab02f19b04825e92be6f074a4a98f6ea1e.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Transparent Shopper',
#   'price': '$29.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/18/1f/181fd55b1e2cb77b170f779cc0b397a8e9c82295.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Small Straw Bag',
#   'price': '$12.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/34/93/3493d79931dd882a0d0f0142ef723cf1d6268e3f.jpg],origin[dam],category[ladies_bags_smallclutch],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Belt Bag',
#   'price': '$19.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/7f/08/7f08f0ed1fa4da59fc82e4c9bf6aee6c22818c67.jpg],origin[dam],category[ladies_bags_smallclutch],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Small Backpack',
#   'price': '$24.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/c2/1d/c21d05dea33fab83da89c8d3940f4ded4e7513e8.jpg],origin[dam],category[ladies_bags_smallclutch],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Belt Bag',
#   'price': '$17.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/7e/f6/7ef6145b84f18e3f588e5f36362141e7392d6595.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Small Suede Shopper',
#   'price': '$49.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/12/0a/120a5fd3e1bd98919dc88b9dd82ab11c3ee27f2a.jpg],origin[dam],category[ladies_bags_smallclutch],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Small Backpack',
#   'price': '$24.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/bf/fc/bffc36046e014ef155bfa3aeb749186475300c90.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Shoulder Bag with Suede Detail',
#   'price': '$29.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/be/c7/bec75551474a80577119b9ad4b7b2ed9b0d4bc76.jpg],origin[dam],category[ladies_bags_shouldercross],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Bag',
#   'price': '$34.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/69/2b/692b0773ec4c7362c62f49b28d8278579662c403.jpg],origin[dam],category[ladies_bags_shouldercross],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Suede Shoulder Bag',
#   'price': '$34.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/d9/f0/d9f0f1535f15e448599ea72c8df315e973ea5886.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Shoulder Bag',
#   'price': '$29.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/d8/2e/d82efbfe9ef5b2ef31e6fb6e39ca7b6db2787bc6.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Shopper',
#   'price': '$24.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/5e/1f/5e1fa7d1ce103d170862f1395092d88f1e95057a.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Mini Pouch Bag',
#   'price': '$9.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/f4/ee/f4eedf43b8530760d0ce3b03d33a5de46485572e.jpg],origin[dam],category[ladies_accessories_other],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Handbag Accessory',
#   'price': '$7.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/70/94/7094c24088db9332c22e0ca174c79828052e3d53.jpg],origin[dam],category[ladies_bags_smallclutch],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Belt Bag',
#   'price': '$17.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/a3/3c/a33cf6165cc72e41a4b6ee8b1d3e4f64bf94d611.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Small Straw Bag',
#   'price': '$12.99'},
#  {'link': 'http://lp2.hm.com/hmgoepprod?set=source[/dc/f5/dcf54deb67b063fdfa0f0911adac61100ba7e54f.jpg],origin[dam],category[ladies_bags_shouldercross],type[DESCRIPTIVESTILLLIFE],res[y],hmver[1]&call=url[file:/product/main]',
#   'description': 'Small Shoulder Bag',
#   'price': '$29.99'}]

# %%
# list of dictionary in dataframe
df_data = pd.DataFrame(all_data)
df_data
# Out:
#                        description  \
# 0    Bucket Bag with Suede Details
# 1               Straw Shoulder Bag
# 2              Paper Straw Shopper
# 3                     Mini Shopper
# 4                          Net Bag
# 5                    Suede Shopper
# 6                  Round Straw Bag
# 7                  Braided Handbag
# 8        Straw Bag with Fabric Bag
# 9               Suede Shoulder Bag
# 10              Small Shoulder Bag
# 11           Waist Belt with Pouch
# 12             Transparent Shopper
# 13                 Small Straw Bag
# 14                        Belt Bag
# 15                  Small Backpack
# 16                        Belt Bag
# 17             Small Suede Shopper
# 18                  Small Backpack
# 19  Shoulder Bag with Suede Detail
# 20                             Bag
# 21              Suede Shoulder Bag
# 22                    Shoulder Bag
# 23                         Shopper
# 24                  Mini Pouch Bag
# 25               Handbag Accessory
# 26                        Belt Bag
# 27                 Small Straw Bag
# 28              Small Shoulder Bag
#
#                                                  link   price
# 0   http://lp2.hm.com/hmgoepprod?set=source[/14/19...  $49.99
# 1   http://lp2.hm.com/hmgoepprod?set=source[/9e/36...  $19.99
# 2   http://lp2.hm.com/hmgoepprod?set=source[/19/58...  $29.99
# 3   http://lp2.hm.com/hmgoepprod?set=source[/21/8c...  $19.99
# 4   http://lp2.hm.com/hmgoepprod?set=source[/b2/bf...  $14.99
# 5   http://lp2.hm.com/hmgoepprod?set=source[/90/8c...  $69.99
# 6   http://lp2.hm.com/hmgoepprod?set=source[/ce/67...  $17.99
# 7   http://lp2.hm.com/hmgoepprod?set=source[/36/ed...  $59.99
# 8   http://lp2.hm.com/hmgoepprod?set=source[/e2/2f...  $29.99
# 9   http://lp2.hm.com/hmgoepprod?set=source[/6f/91...  $49.99
# 10  http://lp2.hm.com/hmgoepprod?set=source[/dc/2e...  $29.99
# 11  http://lp2.hm.com/hmgoepprod?set=source[/d4/e9...  $17.99
# 12  http://lp2.hm.com/hmgoepprod?set=source[/21/bb...  $29.99
# 13  http://lp2.hm.com/hmgoepprod?set=source[/18/1f...  $12.99
# 14  http://lp2.hm.com/hmgoepprod?set=source[/34/93...  $19.99
# 15  http://lp2.hm.com/hmgoepprod?set=source[/7f/08...  $24.99
# 16  http://lp2.hm.com/hmgoepprod?set=source[/c2/1d...  $17.99
# 17  http://lp2.hm.com/hmgoepprod?set=source[/7e/f6...  $49.99
# 18  http://lp2.hm.com/hmgoepprod?set=source[/12/0a...  $24.99
# 19  http://lp2.hm.com/hmgoepprod?set=source[/bf/fc...  $29.99
# 20  http://lp2.hm.com/hmgoepprod?set=source[/be/c7...  $34.99
# 21  http://lp2.hm.com/hmgoepprod?set=source[/69/2b...  $34.99
# 22  http://lp2.hm.com/hmgoepprod?set=source[/d9/f0...  $29.99
# 23  http://lp2.hm.com/hmgoepprod?set=source[/d8/2e...  $24.99
# 24  http://lp2.hm.com/hmgoepprod?set=source[/5e/1f...   $9.99
# 25  http://lp2.hm.com/hmgoepprod?set=source[/f4/ee...   $7.99
# 26  http://lp2.hm.com/hmgoepprod?set=source[/70/94...  $17.99
# 27  http://lp2.hm.com/hmgoepprod?set=source[/a3/3c...  $12.99
# 28  http://lp2.hm.com/hmgoepprod?set=source[/dc/f5...  $29.99

# %%
# save the dataframe as a csv (to merge with other data later)
df_data.to_csv('hm_data.csv')

# %% [markdown]
# ### 2. Loop through image links and save as a .png file

# %%
# loop through the links to request and save image
for i, url in enumerate(links_):
    time.sleep(1)
    try:
        request = urllib.request.Request(url)
        response = urllib.request.urlopen(request)
        binary_str = response.read()
        byte_array = bytearray(binary_str)
        numpy_array = np.asarray(byte_array, dtype='int8')
        image = cv2.imdecode(numpy_array, cv2.IMREAD_UNCHANGED)
        cv2.imwrite("H&M/"+"hm_{}".format(i+1)+".png", image)
        print("Saved "+"hm_{}".format(i+1)+".png")
    except Exception as e:
        print(str(e))

print("Done")
# Out:
# Saved hm_0.png
# Saved hm_1.png
# Saved hm_2.png
# Saved hm_3.png
# Saved hm_4.png
# Saved hm_5.png
# Saved hm_6.png
# Saved hm_7.png
# Saved hm_8.png
# Saved hm_9.png
# Saved hm_10.png
# Saved hm_11.png
# Saved hm_12.png
# Saved hm_13.png
# Saved hm_14.png
# Saved hm_15.png
# Saved hm_16.png
# Saved hm_17.png
# Saved hm_18.png
# Saved hm_19.png
# Saved hm_20.png
# Saved hm_21.png
# Saved hm_22.png
# Saved hm_23.png
# Saved hm_24.png
# Saved hm_25.png
# Saved hm_26.png
# Saved hm_27.png
# Saved hm_28.png
# Done

# %%
df = pd.read_csv('hm_data.csv')
df
# Out:
#     Unnamed: 0                     description  \
# 0            0   Bucket Bag with Suede Details
# 1            1              Straw Shoulder Bag
# 2            2             Paper Straw Shopper
# 3            3                    Mini Shopper
# 4            4                         Net Bag
# 5            5                   Suede Shopper
# 6            6                 Round Straw Bag
# 7            7                 Braided Handbag
# 8            8       Straw Bag with Fabric Bag
# 9            9              Suede Shoulder Bag
# 10          10              Small Shoulder Bag
# 11          11           Waist Belt with Pouch
# 12          12             Transparent Shopper
# 13          13                 Small Straw Bag
# 14          14                        Belt Bag
# 15          15                  Small Backpack
# 16          16                        Belt Bag
# 17          17             Small Suede Shopper
# 18          18                  Small Backpack
# 19          19  Shoulder Bag with Suede Detail
# 20          20                             Bag
# 21          21              Suede Shoulder Bag
# 22          22                    Shoulder Bag
# 23          23                         Shopper
# 24          24                  Mini Pouch Bag
# 25          25               Handbag Accessory
# 26          26                        Belt Bag
# 27          27                 Small Straw Bag
# 28          28              Small Shoulder Bag
#
#                                                  link   price
# 0   http://lp2.hm.com/hmgoepprod?set=source[/14/19...  $49.99
# 1   http://lp2.hm.com/hmgoepprod?set=source[/9e/36...  $19.99
# 2   http://lp2.hm.com/hmgoepprod?set=source[/19/58...  $29.99
# 3   http://lp2.hm.com/hmgoepprod?set=source[/21/8c...  $19.99
# 4   http://lp2.hm.com/hmgoepprod?set=source[/b2/bf...  $14.99
# 5   http://lp2.hm.com/hmgoepprod?set=source[/90/8c...  $69.99
# 6   http://lp2.hm.com/hmgoepprod?set=source[/ce/67...  $17.99
# 7   http://lp2.hm.com/hmgoepprod?set=source[/36/ed...  $59.99
# 8   http://lp2.hm.com/hmgoepprod?set=source[/e2/2f...  $29.99
# 9   http://lp2.hm.com/hmgoepprod?set=source[/6f/91...  $49.99
# 10  http://lp2.hm.com/hmgoepprod?set=source[/dc/2e...  $29.99
# 11  http://lp2.hm.com/hmgoepprod?set=source[/d4/e9...  $17.99
# 12  http://lp2.hm.com/hmgoepprod?set=source[/21/bb...  $29.99
# 13  http://lp2.hm.com/hmgoepprod?set=source[/18/1f...  $12.99
# 14  http://lp2.hm.com/hmgoepprod?set=source[/34/93...  $19.99
# 15  http://lp2.hm.com/hmgoepprod?set=source[/7f/08...  $24.99
# 16  http://lp2.hm.com/hmgoepprod?set=source[/c2/1d...  $17.99
# 17  http://lp2.hm.com/hmgoepprod?set=source[/7e/f6...  $49.99
# 18  http://lp2.hm.com/hmgoepprod?set=source[/12/0a...  $24.99
# 19  http://lp2.hm.com/hmgoepprod?set=source[/bf/fc...  $29.99
# 20  http://lp2.hm.com/hmgoepprod?set=source[/be/c7...  $34.99
# 21  http://lp2.hm.com/hmgoepprod?set=source[/69/2b...  $34.99
# 22  http://lp2.hm.com/hmgoepprod?set=source[/d9/f0...  $29.99
# 23  http://lp2.hm.com/hmgoepprod?set=source[/d8/2e...  $24.99
# 24  http://lp2.hm.com/hmgoepprod?set=source[/5e/1f...   $9.99
# 25  http://lp2.hm.com/hmgoepprod?set=source[/f4/ee...   $7.99
# 26  http://lp2.hm.com/hmgoepprod?set=source[/70/94...  $17.99
# 27  http://lp2.hm.com/hmgoepprod?set=source[/a3/3c...  $12.99
# 28  http://lp2.hm.com/hmgoepprod?set=source[/dc/f5...  $29.99

# %%
df['brand'] = 'H&M'
df['img-file'] = df['Unnamed: 0'].apply(lambda x: 'hm_'+str(x+1)+'.png')
df.drop(labels = 'Unnamed: 0', axis=1, inplace = True)
df
# Out:
#                        description  \
# 0    Bucket Bag with Suede Details
# 1               Straw Shoulder Bag
# 2              Paper Straw Shopper
# 3                     Mini Shopper
# 4                          Net Bag
# 5                    Suede Shopper
# 6                  Round Straw Bag
# 7                  Braided Handbag
# 8        Straw Bag with Fabric Bag
# 9               Suede Shoulder Bag
# 10              Small Shoulder Bag
# 11           Waist Belt with Pouch
# 12             Transparent Shopper
# 13                 Small Straw Bag
# 14                        Belt Bag
# 15                  Small Backpack
# 16                        Belt Bag
# 17             Small Suede Shopper
# 18                  Small Backpack
# 19  Shoulder Bag with Suede Detail
# 20                             Bag
# 21              Suede Shoulder Bag
# 22                    Shoulder Bag
# 23                         Shopper
# 24                  Mini Pouch Bag
# 25               Handbag Accessory
# 26                        Belt Bag
# 27                 Small Straw Bag
# 28              Small Shoulder Bag
#
#                                                  link   price brand   img-file
# 0   http://lp2.hm.com/hmgoepprod?set=source[/14/19...  $49.99   H&M   hm_1.png
# 1   http://lp2.hm.com/hmgoepprod?set=source[/9e/36...  $19.99   H&M   hm_2.png
# 2   http://lp2.hm.com/hmgoepprod?set=source[/19/58...  $29.99   H&M   hm_3.png
# 3   http://lp2.hm.com/hmgoepprod?set=source[/21/8c...  $19.99   H&M   hm_4.png
# 4   http://lp2.hm.com/hmgoepprod?set=source[/b2/bf...  $14.99   H&M   hm_5.png
# 5   http://lp2.hm.com/hmgoepprod?set=source[/90/8c...  $69.99   H&M   hm_6.png
# 6   http://lp2.hm.com/hmgoepprod?set=source[/ce/67...  $17.99   H&M   hm_7.png
# 7   http://lp2.hm.com/hmgoepprod?set=source[/36/ed...  $59.99   H&M   hm_8.png
# 8   http://lp2.hm.com/hmgoepprod?set=source[/e2/2f...  $29.99   H&M   hm_9.png
# 9   http://lp2.hm.com/hmgoepprod?set=source[/6f/91...  $49.99   H&M  hm_10.png
# 10  http://lp2.hm.com/hmgoepprod?set=source[/dc/2e...  $29.99   H&M  hm_11.png
# 11  http://lp2.hm.com/hmgoepprod?set=source[/d4/e9...  $17.99   H&M  hm_12.png
# 12  http://lp2.hm.com/hmgoepprod?set=source[/21/bb...  $29.99   H&M  hm_13.png
# 13  http://lp2.hm.com/hmgoepprod?set=source[/18/1f...  $12.99   H&M  hm_14.png
# 14  http://lp2.hm.com/hmgoepprod?set=source[/34/93...  $19.99   H&M  hm_15.png
# 15  http://lp2.hm.com/hmgoepprod?set=source[/7f/08...  $24.99   H&M  hm_16.png
# 16  http://lp2.hm.com/hmgoepprod?set=source[/c2/1d...  $17.99   H&M  hm_17.png
# 17  http://lp2.hm.com/hmgoepprod?set=source[/7e/f6...  $49.99   H&M  hm_18.png
# 18  http://lp2.hm.com/hmgoepprod?set=source[/12/0a...  $24.99   H&M  hm_19.png
# 19  http://lp2.hm.com/hmgoepprod?set=source[/bf/fc...  $29.99   H&M  hm_20.png
# 20  http://lp2.hm.com/hmgoepprod?set=source[/be/c7...  $34.99   H&M  hm_21.png
# 21  http://lp2.hm.com/hmgoepprod?set=source[/69/2b...  $34.99   H&M  hm_22.png
# 22  http://lp2.hm.com/hmgoepprod?set=source[/d9/f0...  $29.99   H&M  hm_23.png
# 23  http://lp2.hm.com/hmgoepprod?set=source[/d8/2e...  $24.99   H&M  hm_24.png
# 24  http://lp2.hm.com/hmgoepprod?set=source[/5e/1f...   $9.99   H&M  hm_25.png
# 25  http://lp2.hm.com/hmgoepprod?set=source[/f4/ee...   $7.99   H&M  hm_26.png
# 26  http://lp2.hm.com/hmgoepprod?set=source[/70/94...  $17.99   H&M  hm_27.png
# 27  http://lp2.hm.com/hmgoepprod?set=source[/a3/3c...  $12.99   H&M  hm_28.png
# 28  http://lp2.hm.com/hmgoepprod?set=source[/dc/f5...  $29.99   H&M  hm_29.png

# %%
df.to_csv('hm_data.csv')
